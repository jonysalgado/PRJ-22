# %% [markdown]
# # Importations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
df = pd.read_excel('01_aircraft_survey.xlsx')
df.head()
# Out:
#          Parameter  MTOW (kg)  Empty Weight (kg)  Payload Weight (kg)  \
# 0   Boeing 737-800    79016.0            41413.0              14690.0
# 1  Airbus A320-212    73500.0            60500.0              14250.0
# 2       Aircraft_C        NaN                NaN                  NaN
# 3       Aircraft_D        NaN                NaN                  NaN
# 4       Aircraft_E        NaN                NaN                  NaN
#
#    Number of passengers (n)  Baggage compartment volume ($m^3$)  Range (nm)  \
# 0                     184.0                               47.10      2897.0
# 1                     179.0                               38.76      2700.0
# 2                       NaN                                 NaN         NaN
# 3                       NaN                                 NaN         NaN
# 4                       NaN                                 NaN         NaN
#
#    Cruise_Mach  Cruise_altitude_(ft)  Service_ceiling  ...  \
# 0         0.84               35000.0          41000.0  ...
# 1         0.79               28000.0              NaN  ...
# 2          NaN                   NaN              NaN  ...
# 3          NaN                   NaN              NaN  ...
# 4          NaN                   NaN              NaN  ...
#
#    Number_of_window_exits  Number_of_engines_(n)     Engine_location  \
# 0                     NaN                    2.0  wing_lower_surface
# 1                     4.0                    2.0  wing_lower_surface
# 2                     NaN                    NaN                 NaN
# 3                     NaN                    NaN                 NaN
# 4                     NaN                    NaN                 NaN
#
#    Total_maximum_thrust_(kN,each)  Engine_TSFC  Wing_loading_(kg/m²)  \
# 0                             NaN          NaN                627.77
# 1                           111.2          NaN                600.49
# 2                             NaN          NaN                   NaN
# 3                             NaN          NaN                   NaN
# 4                             NaN          NaN                   NaN
#
#    Thrust-to-weight_ratio Landing_gear_configuration  \
# 0                  0.2789              TRICYCLE-TYPE
# 1                  0.3084              TRICYCLE-TYPE
# 2                     NaN                        NaN
# 3                     NaN                        NaN
# 4                     NaN                        NaN
#
#    Number_of_wheels_of_the_NLG  Number_of_wheels_of_the_MLG
# 0                          2.0                          4.0
# 1                          2.0                          4.0
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
# [5 rows x 48 columns]

# %%
df.columns[32]
# Out:
# 'Fuselage_length_(m)'

# %%
X, y = df.iloc[:2, 1], df.iloc[:2, 2]
z = np.polyfit(X, y, 2)
# Out:
# /home/jony/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
p = np.poly1d(z)

# %%
y_pred = p(np.sort(X))

# %%
plt.figure(figsize=(12,8))
plt.scatter(X, y, label="fit")
plt.plot(np.sort(X), y_pred, color='red', label="Dados experimentais")
plt.grid(True)
plt.legend()
plt.xlabel(df.columns[1])
plt.ylabel(df.columns[2])
plt.show()
